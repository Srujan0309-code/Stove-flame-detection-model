# %% [markdown]
# <a href="https://colab.research.google.com/github/Srujan0309-code/.github/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-91fd38b8-a068-4625-abc2-fd18332d2142" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-91fd38b8-a068-4625-abc2-fd18332d2142">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

zip_path = "/content/stove-flame detection.v2i.yolov8.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/data")

# %%
# !ls /content/data
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 37.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(
    data="/content/data/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.4.48 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls /content/runs/detect/train
# Out:
# args.yaml			 results.csv	       val_batch0_labels.jpg
# BoxF1_curve.png			 results.png	       val_batch0_pred.jpg
# BoxP_curve.png			 train_batch0.jpg      val_batch1_labels.jpg
# BoxPR_curve.png			 train_batch14360.jpg  val_batch1_pred.jpg
# BoxR_curve.png			 train_batch14361.jpg  val_batch2_labels.jpg
# confusion_matrix_normalized.png  train_batch14362.jpg  val_batch2_pred.jpg
# confusion_matrix.png		 train_batch1.jpg      weights
# labels.jpg			 train_batch2.jpg

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e48d2156-a66d-4dcb-9792-4a87299d346d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e48d2156-a66d-4dcb-9792-4a87299d346d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model.predict(
    source="/content/20230701_183818_jpg.rf.64b77a70bd7e40ea8d7e22e648451327.jpg",
    conf=0.5,
    save=True
)
# Out:
# image 1/1 /content/20230701_183818_jpg.rf.64b77a70bd7e40ea8d7e22e648451327.jpg: 640x640 2 burnings, 8.7ms
# Speed: 3.0ms preprocess, 8.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'burning', 1: 'non-burning'}
#  obb: None
#  orig_img: array([[[ 90, 104, 100],
#          [ 90, 104, 100],
#          [ 90, 104, 100],
#          ...,
#          [127, 139, 143],
#          [127, 139, 143],
#          [127, 139, 143]],
#
#         [[ 90, 104, 100],
#          [ 90, 104, 100],
#          [ 90, 104, 100],
#          ...,
#          [127, 139, 143],
#          [127, 139, 143],
#          [127, 139, 143]],
#
#         [[ 90, 104, 100],
#          [ 90, 104, 100],
#          [ 90, 104, 100],
#          ...,
#          [125, 140, 143],
#          [125, 140, 143],
# ...

# %%
from IPython.display import Image

Image(filename='/content/runs/detect/predict/20230701_183818_jpg.rf.64b77a70bd7e40ea8d7e22e648451327.jpg')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-55c2fe28-632c-4b9c-8838-a98bec046f3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55c2fe28-632c-4b9c-8838-a98bec046f3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model.predict(
    source="/content/20230701_183818_jpg.rf.64b77a70bd7e40ea8d7e22e648451327.jpg",
    conf=0.5,
    save=True
)
# Out:
# image 1/1 /content/20230701_183818_jpg.rf.64b77a70bd7e40ea8d7e22e648451327.jpg: 640x640 2 burnings, 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'burning', 1: 'non-burning'}
#  obb: None
#  orig_img: array([[[ 90, 104, 100],
#          [ 90, 104, 100],
#          [ 90, 104, 100],
#          ...,
#          [127, 139, 143],
#          [127, 139, 143],
#          [127, 139, 143]],
#
#         [[ 90, 104, 100],
#          [ 90, 104, 100],
#          [ 90, 104, 100],
#          ...,
#          [127, 139, 143],
#          [127, 139, 143],
#          [127, 139, 143]],
#
#         [[ 90, 104, 100],
#          [ 90, 104, 100],
#          [ 90, 104, 100],
#          ...,
#          [125, 140, 143],
#          [125, 140, 143],
# ...

# %%
model.predict(
    source="/content/gasstove-19_jpg.rf.de1d5a085e5c23658bd12b9e397f931a.jpg",
    conf=0.5,
    save=True
)
# Out:
# image 1/1 /content/gasstove-19_jpg.rf.de1d5a085e5c23658bd12b9e397f931a.jpg: 640x512 2 non-burnings, 43.9ms
# Speed: 4.8ms preprocess, 43.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'burning', 1: 'non-burning'}
#  obb: None
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
# ...

# %%
from IPython.display import Image

Image(filename='/content/runs/detect/predict/gasstove-19_jpg.rf.de1d5a085e5c23658bd12b9e397f931a.jpg')

# %%
# !ls /content/runs/detect/train/weights
# Out:
# best.pt  last.pt

# %%
from google.colab import files

files.download('/content/runs/detect/train/weights/best.pt')
